# %% [markdown]
# # Using CLIPTextC
# ## Dataset
# ### (i) emotions

# %%
! python main.py --test --dataset emotion
# Out:
# Fix random seed to 42
# test:
# 	macro_f1: 0.17180595749600622
# 	micro_f1: 0.21985949065361937
# 	weighted_f1: 0.21829226661061857
# 	acc: 0.21985949065361937
# {'model': 'clip_ood', 'text_prompt': False, 'dataset': 'emotion', 'test': True, 'batch_size': 128, 'epochs': 5, 'lr': 0.001, 'plm_lr': 0, 'n_tokens': 5, 'ensemble_size': 1, 'threshold': 0.25, 'multi_threshold': 0.225, 'data_dir': './data', 'clip_dir': 'ViT-B/32', 'cache_dir': './outputs', 'use_cache': False, 'seed': 42, 'max_input_length': 77, 'key_score': 'weighted_f1', 'name': 'clip_ood_emotion_no_prompt', 'Model': <class 'model.clip_ood.Model'>, 'device': 'cpu'}
# ...
# converting to features: 100%|##########| 15942/15942 [00:05<00:00, 2974.36it/s]
#
# ...
# test: 100%|##########| 125/125 [18:10<00:00,  8.72s/it]

# %% [markdown]
# ### (ii) Situation

# %%
! python main.py --test --dataset situation
# Out:
# Fix random seed to 42
# test:
# 	macro_f1: 0.3164896856963489
# 	micro_f1: 0.35007496251874065
# 	weighted_f1: 0.3742396066898244
# 	acc: 0.22099290780141845
# {'model': 'clip_multi', 'text_prompt': False, 'dataset': 'situation', 'test': True, 'batch_size': 128, 'epochs': 5, 'lr': 0.001, 'plm_lr': 0, 'n_tokens': 5, 'ensemble_size': 1, 'threshold': 0.25, 'multi_threshold': 0.225, 'data_dir': './data', 'clip_dir': 'ViT-B/32', 'cache_dir': './outputs', 'use_cache': False, 'seed': 42, 'max_input_length': 77, 'key_score': 'weighted_f1', 'name': 'clip_multi_situation_no_prompt', 'Model': <class 'model.clip_multi.Model'>, 'device': 'cpu'}
# ...
# converting to features: 100%|##########| 3525/3525 [00:02<00:00, 1502.57it/s]
#
# ...
# test: 100%|##########| 28/28 [06:02<00:00, 12.93s/it]

# %% [markdown]
# ### (iii) AG's News

# %%
! python main.py --test --dataset agnews
# Out:
# Fix random seed to 42
# test:
# 	macro_f1: 0.7636115687152001
# 	micro_f1: 0.7697368421052632
# 	weighted_f1: 0.7636115687152001
# 	acc: 0.7697368421052632
# {'model': 'clip_single', 'text_prompt': False, 'dataset': 'agnews', 'test': True, 'batch_size': 128, 'epochs': 5, 'lr': 0.001, 'plm_lr': 0, 'n_tokens': 5, 'ensemble_size': 1, 'threshold': 0.25, 'multi_threshold': 0.225, 'data_dir': './data', 'clip_dir': 'ViT-B/32', 'cache_dir': './outputs', 'use_cache': False, 'seed': 42, 'max_input_length': 77, 'key_score': 'acc', 'name': 'clip_single_agnews_no_prompt', 'Model': <class 'model.clip_single.Model'>, 'device': 'cpu'}
# ...
# converting to features: 100%|##########| 7600/7600 [00:04<00:00, 1628.87it/s]
#
# ...
# test: 100%|##########| 60/60 [10:54<00:00, 10.91s/it]

# %% [markdown]
# ### (iv) Snips

# %%
! python main.py --test --dataset snips
# Out:
# Fix random seed to 42
# test:
# 	macro_f1: 0.8116266223970968
# 	micro_f1: 0.81
# 	weighted_f1: 0.8114922391981835
# 	acc: 0.81
# {'model': 'clip_single', 'text_prompt': False, 'dataset': 'snips', 'test': True, 'batch_size': 128, 'epochs': 5, 'lr': 0.001, 'plm_lr': 0, 'n_tokens': 5, 'ensemble_size': 1, 'threshold': 0.25, 'multi_threshold': 0.225, 'data_dir': './data', 'clip_dir': 'ViT-B/32', 'cache_dir': './outputs', 'use_cache': False, 'seed': 42, 'max_input_length': 77, 'key_score': 'acc', 'name': 'clip_single_snips_no_prompt', 'Model': <class 'model.clip_single.Model'>, 'device': 'cpu'}
# ...
# converting to features: 100%|##########| 700/700 [00:00<00:00, 3316.51it/s]
#
# ...
# test: 100%|##########| 6/6 [00:47<00:00,  7.94s/it]

# %% [markdown]
# ### (v) Trec

# %%
! python main.py --test --dataset trec
# Out:
# Fix random seed to 42
# test:
# 	macro_f1: 0.40010443292594416
# 	micro_f1: 0.416
# 	weighted_f1: 0.40957171460268954
# 	acc: 0.416
# {'model': 'clip_single', 'text_prompt': False, 'dataset': 'trec', 'test': True, 'batch_size': 128, 'epochs': 5, 'lr': 0.001, 'plm_lr': 0, 'n_tokens': 5, 'ensemble_size': 1, 'threshold': 0.25, 'multi_threshold': 0.225, 'data_dir': './data', 'clip_dir': 'ViT-B/32', 'cache_dir': './outputs', 'use_cache': False, 'seed': 42, 'max_input_length': 77, 'key_score': 'acc', 'name': 'clip_single_trec_no_prompt', 'Model': <class 'model.clip_single.Model'>, 'device': 'cpu'}
# ...
# converting to features: 100%|##########| 500/500 [00:00<00:00, 3280.00it/s]
#
# ...
# test: 100%|##########| 4/4 [00:33<00:00,  8.39s/it]

# %% [markdown]
# ### (vi) Subj

# %%
! python main.py --test --dataset subj
# Out:
# Fix random seed to 42
# test:
# 	macro_f1: 0.6108196348857071
# 	micro_f1: 0.63
# 	weighted_f1: 0.610819634885707
# 	acc: 0.63
# {'model': 'clip_single', 'text_prompt': False, 'dataset': 'subj', 'test': True, 'batch_size': 128, 'epochs': 5, 'lr': 0.001, 'plm_lr': 0, 'n_tokens': 5, 'ensemble_size': 1, 'threshold': 0.25, 'multi_threshold': 0.225, 'data_dir': './data', 'clip_dir': 'ViT-B/32', 'cache_dir': './outputs', 'use_cache': False, 'seed': 42, 'max_input_length': 77, 'key_score': 'acc', 'name': 'clip_single_subj_no_prompt', 'Model': <class 'model.clip_single.Model'>, 'device': 'cpu'}
# C:\Users\abdul\anaconda3\envs\great\lib\site-packages\PIL\Image.py:996: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
#
# ...
# converting to features: 100%|##########| 1000/1000 [00:00<00:00, 1950.10it/s]
#
# ...
# test: 100%|##########| 8/8 [01:00<00:00,  7.60s/it]

# %% [markdown]
# # Using Prompt-CLIPTextC
# ## Dataset
# ### (i) emotion

# %%
! python main.py --test --text_prompt --dataset emotion
# Out:
# Fix random seed to 42
# test:
# 	macro_f1: 0.16879780799955763
# 	micro_f1: 0.20913310751474093
# 	weighted_f1: 0.21252815129795646
# 	acc: 0.20913310751474093
# {'model': 'clip_ood', 'text_prompt': True, 'dataset': 'emotion', 'test': True, 'batch_size': 128, 'epochs': 5, 'lr': 0.001, 'plm_lr': 0, 'n_tokens': 5, 'ensemble_size': 1, 'threshold': 0.25, 'multi_threshold': 0.225, 'data_dir': './data', 'clip_dir': 'ViT-B/32', 'cache_dir': './outputs', 'use_cache': False, 'seed': 42, 'max_input_length': 77, 'key_score': 'weighted_f1', 'name': 'clip_ood_emotion_text_promt', 'Model': <class 'model.clip_ood.Model'>, 'device': 'cpu'}
# ...
# converting to features: 100%|##########| 15942/15942 [00:05<00:00, 2730.78it/s]
#
# ...
# test: 100%|##########| 125/125 [18:21<00:00,  8.81s/it]

# %% [markdown]
# ### (ii) Situation

# %%
! python main.py --test --text_prompt --dataset situation
# Out:
# Fix random seed to 42
# test:
# 	macro_f1: 0.3352040683531255
# 	micro_f1: 0.36489076274434645
# 	weighted_f1: 0.38804662564523784
# 	acc: 0.22921985815602836
# {'model': 'clip_multi', 'text_prompt': True, 'dataset': 'situation', 'test': True, 'batch_size': 128, 'epochs': 5, 'lr': 0.001, 'plm_lr': 0, 'n_tokens': 5, 'ensemble_size': 1, 'threshold': 0.25, 'multi_threshold': 0.225, 'data_dir': './data', 'clip_dir': 'ViT-B/32', 'cache_dir': './outputs', 'use_cache': False, 'seed': 42, 'max_input_length': 77, 'key_score': 'weighted_f1', 'name': 'clip_multi_situation_text_promt', 'Model': <class 'model.clip_multi.Model'>, 'device': 'cpu'}
# ...
# converting to features: 100%|##########| 3525/3525 [00:02<00:00, 1693.09it/s]
#
# ...
# test: 100%|##########| 28/28 [04:51<00:00, 10.40s/it]

# %% [markdown]
# ### (iii) AG's News

# %%
! python main.py --test --text_prompt --dataset agnews
# Out:
# Fix random seed to 42
# test:
# 	macro_f1: 0.779486675613698
# 	micro_f1: 0.7843421052631578
# 	weighted_f1: 0.779486675613698
# 	acc: 0.7843421052631578
# {'model': 'clip_single', 'text_prompt': True, 'dataset': 'agnews', 'test': True, 'batch_size': 128, 'epochs': 5, 'lr': 0.001, 'plm_lr': 0, 'n_tokens': 5, 'ensemble_size': 1, 'threshold': 0.25, 'multi_threshold': 0.225, 'data_dir': './data', 'clip_dir': 'ViT-B/32', 'cache_dir': './outputs', 'use_cache': False, 'seed': 42, 'max_input_length': 77, 'key_score': 'acc', 'name': 'clip_single_agnews_text_promt', 'Model': <class 'model.clip_single.Model'>, 'device': 'cpu'}
# ...
# converting to features: 100%|##########| 7600/7600 [00:03<00:00, 1981.84it/s]
#
# ...
# test: 100%|##########| 60/60 [06:00<00:00,  6.01s/it]

# %% [markdown]
# ### (iv) Snips

# %%
! python main.py --test --text_prompt --dataset snips
# Out:
# Fix random seed to 42
# test:
# 	macro_f1: 0.8224526058349895
# 	micro_f1: 0.8185714285714286
# 	weighted_f1: 0.8203300083106774
# 	acc: 0.8185714285714286
# {'model': 'clip_single', 'text_prompt': True, 'dataset': 'snips', 'test': True, 'batch_size': 128, 'epochs': 5, 'lr': 0.001, 'plm_lr': 0, 'n_tokens': 5, 'ensemble_size': 1, 'threshold': 0.25, 'multi_threshold': 0.225, 'data_dir': './data', 'clip_dir': 'ViT-B/32', 'cache_dir': './outputs', 'use_cache': False, 'seed': 42, 'max_input_length': 77, 'key_score': 'acc', 'name': 'clip_single_snips_text_promt', 'Model': <class 'model.clip_single.Model'>, 'device': 'cpu'}
# ...
# converting to features: 100%|##########| 700/700 [00:00<00:00, 3351.20it/s]
#
# ...
# test: 100%|##########| 6/6 [00:34<00:00,  5.80s/it]

# %% [markdown]
# ### (v) Trec

# %%
! python main.py --test --text_prompt --dataset trec
# Out:
# Fix random seed to 42
# test:
# 	macro_f1: 0.4879739491946065
# 	micro_f1: 0.484
# 	weighted_f1: 0.4753132678901693
# 	acc: 0.484
# {'model': 'clip_single', 'text_prompt': True, 'dataset': 'trec', 'test': True, 'batch_size': 128, 'epochs': 5, 'lr': 0.001, 'plm_lr': 0, 'n_tokens': 5, 'ensemble_size': 1, 'threshold': 0.25, 'multi_threshold': 0.225, 'data_dir': './data', 'clip_dir': 'ViT-B/32', 'cache_dir': './outputs', 'use_cache': False, 'seed': 42, 'max_input_length': 77, 'key_score': 'acc', 'name': 'clip_single_trec_text_promt', 'Model': <class 'model.clip_single.Model'>, 'device': 'cpu'}
# ...
# converting to features: 100%|##########| 500/500 [00:00<00:00, 3088.19it/s]
#
# ...
# test: 100%|##########| 4/4 [00:25<00:00,  6.26s/it]

# %% [markdown]
# ### (vi) Subj

# %%
! python main.py --test --text_prompt --dataset subj
# Out:
# Fix random seed to 42
# test:
# 	macro_f1: 0.683021738671046
# 	micro_f1: 0.685
# 	weighted_f1: 0.683021738671046
# 	acc: 0.685
# {'model': 'clip_single', 'text_prompt': True, 'dataset': 'subj', 'test': True, 'batch_size': 128, 'epochs': 5, 'lr': 0.001, 'plm_lr': 0, 'n_tokens': 5, 'ensemble_size': 1, 'threshold': 0.25, 'multi_threshold': 0.225, 'data_dir': './data', 'clip_dir': 'ViT-B/32', 'cache_dir': './outputs', 'use_cache': False, 'seed': 42, 'max_input_length': 77, 'key_score': 'acc', 'name': 'clip_single_subj_text_promt', 'Model': <class 'model.clip_single.Model'>, 'device': 'cpu'}
# C:\Users\abdul\anaconda3\envs\github-repo-run\lib\site-packages\PIL\Image.py:996: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
#
# ...
# converting to features: 100%|##########| 1000/1000 [00:00<00:00, 1905.80it/s]
#
# ...
# test: 100%|##########| 8/8 [00:46<00:00,  5.78s/it]

# %% [markdown]
# # Using Ensemble Technique(CLIPTEXTC)
# ## Dataset
# ### (i) Emotion

# %%
! python main.py --test --ensemble_size 2 --dataset emotion
# Out:
# Fix random seed to 42
# test:
# 	macro_f1: 0.1934138158838722
# 	micro_f1: 0.2446368084305608
# 	weighted_f1: 0.24720192031014726
# 	acc: 0.2446368084305608
# {'model': 'clip_ood', 'text_prompt': False, 'dataset': 'emotion', 'test': True, 'batch_size': 128, 'epochs': 5, 'lr': 0.001, 'plm_lr': 0, 'n_tokens': 5, 'ensemble_size': 2, 'threshold': 0.25, 'multi_threshold': 0.225, 'data_dir': './data', 'clip_dir': 'ViT-B/32', 'cache_dir': './outputs', 'use_cache': False, 'seed': 42, 'max_input_length': 77, 'key_score': 'weighted_f1', 'name': 'clip_ood_emotion_no_prompt', 'Model': <class 'model.clip_ood.Model'>, 'device': 'cpu'}
# ...
# converting to features: 100%|##########| 15942/15942 [00:05<00:00, 2820.19it/s]
#
# ...
# test: 100%|##########| 125/125 [14:38<00:00,  7.03s/it]

# %% [markdown]
# ### (ii) Situation

# %%
! python main.py --test --ensemble_size 2 --dataset situation
# Out:
# Fix random seed to 42
# ...
# converting to features: 100%|##########| 3525/3525 [00:02<00:00, 1704.07it/s]
#
# ...
# test: 100%|##########| 28/28 [03:17<00:00,  7.06s/it]
# test:
# 	macro_f1: 0.31692970049258995
# 	micro_f1: 0.36524856145646634
# 	weighted_f1: 0.37877196041674616
# 	acc: 0.2326241134751773
# {'model': 'clip_multi', 'text_prompt': False, 'dataset': 'situation', 'test': True, 'batch_size': 128, 'epochs': 5, 'lr': 0.001, 'plm_lr': 0, 'n_tokens': 5, 'ensemble_size': 2, 'threshold': 0.25, 'multi_threshold': 0.225, 'data_dir': './data', 'clip_dir': 'ViT-B/32', 'cache_dir': './outputs', 'use_cache': False, 'seed': 42, 'max_input_length': 77, 'key_score': 'weighted_f1', 'name': 'clip_multi_situation_no_prompt', 'Model': <class 'model.clip_multi.Model'>, 'device': 'cpu'}

# %% [markdown]
# ### (iii) AG's News

# %%
! python main.py --test --ensemble_size 2 --dataset agnews
# Out:
# Fix random seed to 42
# test:
# 	macro_f1: 0.7704818459532436
# 	micro_f1: 0.7746052631578947
# 	weighted_f1: 0.7704818459532436
# 	acc: 0.7746052631578947
# {'model': 'clip_single', 'text_prompt': False, 'dataset': 'agnews', 'test': True, 'batch_size': 128, 'epochs': 5, 'lr': 0.001, 'plm_lr': 0, 'n_tokens': 5, 'ensemble_size': 2, 'threshold': 0.25, 'multi_threshold': 0.225, 'data_dir': './data', 'clip_dir': 'ViT-B/32', 'cache_dir': './outputs', 'use_cache': False, 'seed': 42, 'max_input_length': 77, 'key_score': 'acc', 'name': 'clip_single_agnews_no_prompt', 'Model': <class 'model.clip_single.Model'>, 'device': 'cpu'}
# ...
# converting to features: 100%|##########| 7600/7600 [00:04<00:00, 1885.99it/s]
#
# ...
# test: 100%|##########| 60/60 [06:55<00:00,  6.93s/it]

# %% [markdown]
# ### (iv) Snips

# %%
! python main.py --test --ensemble_size 2 --dataset snips
# Out:
# Fix random seed to 42
# test:
# 	macro_f1: 0.833269601527739
# 	micro_f1: 0.8285714285714286
# 	weighted_f1: 0.8320069196993258
# 	acc: 0.8285714285714286
# {'model': 'clip_single', 'text_prompt': False, 'dataset': 'snips', 'test': True, 'batch_size': 128, 'epochs': 5, 'lr': 0.001, 'plm_lr': 0, 'n_tokens': 5, 'ensemble_size': 2, 'threshold': 0.25, 'multi_threshold': 0.225, 'data_dir': './data', 'clip_dir': 'ViT-B/32', 'cache_dir': './outputs', 'use_cache': False, 'seed': 42, 'max_input_length': 77, 'key_score': 'acc', 'name': 'clip_single_snips_no_prompt', 'Model': <class 'model.clip_single.Model'>, 'device': 'cpu'}
# ...
# converting to features: 100%|##########| 700/700 [00:00<00:00, 3467.33it/s]
#
# ...
# test: 100%|##########| 6/6 [00:35<00:00,  5.98s/it]

# %% [markdown]
# ### (v) Trec

# %%
! python main.py --test --ensemble_size 2 --dataset trec
# Out:
# Fix random seed to 42
# test:
# 	macro_f1: 0.4393764402287322
# 	micro_f1: 0.462
# 	weighted_f1: 0.4495318150126843
# 	acc: 0.462
# {'model': 'clip_single', 'text_prompt': False, 'dataset': 'trec', 'test': True, 'batch_size': 128, 'epochs': 5, 'lr': 0.001, 'plm_lr': 0, 'n_tokens': 5, 'ensemble_size': 2, 'threshold': 0.25, 'multi_threshold': 0.225, 'data_dir': './data', 'clip_dir': 'ViT-B/32', 'cache_dir': './outputs', 'use_cache': False, 'seed': 42, 'max_input_length': 77, 'key_score': 'acc', 'name': 'clip_single_trec_no_prompt', 'Model': <class 'model.clip_single.Model'>, 'device': 'cpu'}
# ...
# converting to features: 100%|##########| 500/500 [00:00<00:00, 3474.22it/s]
#
# ...
# test: 100%|##########| 4/4 [00:25<00:00,  6.26s/it]

# %% [markdown]
# ### (vi) Subj

# %%
! python main.py --test --ensemble_size 2 --dataset subj
# Out:
# Fix random seed to 42
# test:
# 	macro_f1: 0.6828644501278773
# 	micro_f1: 0.69
# 	weighted_f1: 0.6828644501278772
# 	acc: 0.69
# {'model': 'clip_single', 'text_prompt': False, 'dataset': 'subj', 'test': True, 'batch_size': 128, 'epochs': 5, 'lr': 0.001, 'plm_lr': 0, 'n_tokens': 5, 'ensemble_size': 2, 'threshold': 0.25, 'multi_threshold': 0.225, 'data_dir': './data', 'clip_dir': 'ViT-B/32', 'cache_dir': './outputs', 'use_cache': False, 'seed': 42, 'max_input_length': 77, 'key_score': 'acc', 'name': 'clip_single_subj_no_prompt', 'Model': <class 'model.clip_single.Model'>, 'device': 'cpu'}
# C:\Users\abdul\anaconda3\envs\github-repo-run\lib\site-packages\PIL\Image.py:996: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
#
# ...
# converting to features: 100%|##########| 1000/1000 [00:00<00:00, 2080.11it/s]
#
# ...
# test: 100%|##########| 8/8 [00:46<00:00,  5.81s/it]

# %% [markdown]
# # Using Ensemble Technique (PROMPT-CLIPTEXTC)
# ## Dataset
#
# ### (i) Emotion

# %%
! python main.py --test --text_prompt --ensemble_size 2 --dataset emotion
# Out:
# Fix random seed to 42
# test:
# 	macro_f1: 0.18726679555132658
# 	micro_f1: 0.23365951574457408
# 	weighted_f1: 0.2373118690983369
# 	acc: 0.23365951574457408
# {'model': 'clip_ood', 'text_prompt': True, 'dataset': 'emotion', 'test': True, 'batch_size': 128, 'epochs': 5, 'lr': 0.001, 'plm_lr': 0, 'n_tokens': 5, 'ensemble_size': 2, 'threshold': 0.25, 'multi_threshold': 0.225, 'data_dir': './data', 'clip_dir': 'ViT-B/32', 'cache_dir': './outputs', 'use_cache': False, 'seed': 42, 'max_input_length': 77, 'key_score': 'weighted_f1', 'name': 'clip_ood_emotion_text_promt', 'Model': <class 'model.clip_ood.Model'>, 'device': 'cpu'}
# ...
# converting to features: 100%|##########| 15942/15942 [00:05<00:00, 3013.05it/s]
#
# ...
# test: 100%|##########| 125/125 [14:25<00:00,  6.92s/it]

# %% [markdown]
# ### (ii) Situation

# %%
! python main.py --test --text_prompt --ensemble_size 2 --dataset situation
# Out:
# Fix random seed to 42
# test:
# 	macro_f1: 0.3368817880672889
# 	micro_f1: 0.38661999222092575
# 	weighted_f1: 0.3960298203871643
# 	acc: 0.24822695035460993
# {'model': 'clip_multi', 'text_prompt': True, 'dataset': 'situation', 'test': True, 'batch_size': 128, 'epochs': 5, 'lr': 0.001, 'plm_lr': 0, 'n_tokens': 5, 'ensemble_size': 2, 'threshold': 0.25, 'multi_threshold': 0.225, 'data_dir': './data', 'clip_dir': 'ViT-B/32', 'cache_dir': './outputs', 'use_cache': False, 'seed': 42, 'max_input_length': 77, 'key_score': 'weighted_f1', 'name': 'clip_multi_situation_text_promt', 'Model': <class 'model.clip_multi.Model'>, 'device': 'cpu'}
# ...
# converting to features: 100%|##########| 3525/3525 [00:01<00:00, 1929.05it/s]
#
# ...
# test: 100%|##########| 28/28 [03:17<00:00,  7.06s/it]

# %% [markdown]
# ### (iii) AG's News

# %%
! python main.py --test --text_prompt --ensemble_size 2 --dataset agnews
# Out:
# Fix random seed to 42
# ...
# converting to features: 100%|##########| 7600/7600 [00:03<00:00, 2160.31it/s]
#
# ...
# test: 100%|##########| 60/60 [06:17<00:00,  6.29s/it]
# test:
# 	macro_f1: 0.7912517923259197
# 	micro_f1: 0.7935526315789473
# 	weighted_f1: 0.7912517923259197
# 	acc: 0.7935526315789474
# {'model': 'clip_single', 'text_prompt': True, 'dataset': 'agnews', 'test': True, 'batch_size': 128, 'epochs': 5, 'lr': 0.001, 'plm_lr': 0, 'n_tokens': 5, 'ensemble_size': 2, 'threshold': 0.25, 'multi_threshold': 0.225, 'data_dir': './data', 'clip_dir': 'ViT-B/32', 'cache_dir': './outputs', 'use_cache': False, 'seed': 42, 'max_input_length': 77, 'key_score': 'acc', 'name': 'clip_single_agnews_text_promt', 'Model': <class 'model.clip_single.Model'>, 'device': 'cpu'}

# %% [markdown]
# ### (iv) Snips

# %%
! python main.py --test --text_prompt --ensemble_size 2 --dataset snips
# Out:
# Fix random seed to 42
# test:
# 	macro_f1: 0.8513720465438437
# 	micro_f1: 0.8471428571428571
# 	weighted_f1: 0.8495573142340793
# 	acc: 0.8471428571428572
# {'model': 'clip_single', 'text_prompt': True, 'dataset': 'snips', 'test': True, 'batch_size': 128, 'epochs': 5, 'lr': 0.001, 'plm_lr': 0, 'n_tokens': 5, 'ensemble_size': 2, 'threshold': 0.25, 'multi_threshold': 0.225, 'data_dir': './data', 'clip_dir': 'ViT-B/32', 'cache_dir': './outputs', 'use_cache': False, 'seed': 42, 'max_input_length': 77, 'key_score': 'acc', 'name': 'clip_single_snips_text_promt', 'Model': <class 'model.clip_single.Model'>, 'device': 'cpu'}
# ...
# converting to features: 100%|##########| 700/700 [00:00<00:00, 3319.43it/s]
#
# ...
# test: 100%|##########| 6/6 [00:36<00:00,  6.09s/it]

# %% [markdown]
# ### (v) Trec

# %%
! python main.py --test --text_prompt --ensemble_size 2 --dataset trec
# Out:
# Fix random seed to 42
# test:
# 	macro_f1: 0.49100297882424443
# 	micro_f1: 0.516
# 	weighted_f1: 0.4902269741390655
# 	acc: 0.516
# {'model': 'clip_single', 'text_prompt': True, 'dataset': 'trec', 'test': True, 'batch_size': 128, 'epochs': 5, 'lr': 0.001, 'plm_lr': 0, 'n_tokens': 5, 'ensemble_size': 2, 'threshold': 0.25, 'multi_threshold': 0.225, 'data_dir': './data', 'clip_dir': 'ViT-B/32', 'cache_dir': './outputs', 'use_cache': False, 'seed': 42, 'max_input_length': 77, 'key_score': 'acc', 'name': 'clip_single_trec_text_promt', 'Model': <class 'model.clip_single.Model'>, 'device': 'cpu'}
# ...
# converting to features: 100%|##########| 500/500 [00:00<00:00, 3269.85it/s]
#
# ...
# test: 100%|##########| 4/4 [00:28<00:00,  7.03s/it]

# %% [markdown]
# ### (vi) Subj

# %%
! python main.py --test --text_prompt --ensemble_size 2 --dataset subj
# Out:
# Fix random seed to 42
# test:
# 	macro_f1: 0.7407508615779764
# 	micro_f1: 0.7410000000000001
# 	weighted_f1: 0.7407508615779763
# 	acc: 0.741
# {'model': 'clip_single', 'text_prompt': True, 'dataset': 'subj', 'test': True, 'batch_size': 128, 'epochs': 5, 'lr': 0.001, 'plm_lr': 0, 'n_tokens': 5, 'ensemble_size': 2, 'threshold': 0.25, 'multi_threshold': 0.225, 'data_dir': './data', 'clip_dir': 'ViT-B/32', 'cache_dir': './outputs', 'use_cache': False, 'seed': 42, 'max_input_length': 77, 'key_score': 'acc', 'name': 'clip_single_subj_text_promt', 'Model': <class 'model.clip_single.Model'>, 'device': 'cpu'}
# C:\Users\abdul\anaconda3\envs\github-repo-run\lib\site-packages\PIL\Image.py:996: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
#
# ...
# converting to features: 100%|##########| 1000/1000 [00:00<00:00, 1981.45it/s]
#
# ...
# test: 100%|##########| 8/8 [00:49<00:00,  6.20s/it]
